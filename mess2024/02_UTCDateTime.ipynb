# %% [markdown]
# <div style='background-image: url("../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">ObsPy Tutorial</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Handling Time</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Seismo-Live: http://seismo-live.org
#
# ##### Authors:
# * Lion Krischer ([@krischer](https://github.com/krischer))
# * Tobias Megies ([@megies](https://github.com/megies))
# ---

# %% [markdown]
# ![](images/obspy_logo_full_524x179px.png)

# %% [markdown]
# This is a bit dry but not very difficult and important to know. It is used everywhere in ObsPy!
#
#
# * All absolute time values are consistently handled with this class
# * Based on a double precision POSIX timestamp for accuracy
# * Timezone can be specified at initialization (if necessary)
# * In Coordinated Universal Time (UTC) so no need to deal with timezones, daylight savings, ...
#
# ---

# %%
from __future__ import print_function

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ---
#
# ## Features of **`UTCDateTime`**
#
# #### Initialization

# %%
from obspy import UTCDateTime
# import obspy
print(UTCDateTime("2011-03-11T05:46:23.2"))        # mostly time strings defined by ISO standard
print(UTCDateTime("2011-03-11T14:46:23.2+09:00"))  # non-UTC timezone input
print(UTCDateTime(2011, 3, 11, 5, 46, 23, 2))
print(UTCDateTime(1299822383.2))
# Out:
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.200000Z
# 2011-03-11T05:46:23.000002Z
# 2011-03-11T05:46:23.200000Z

# %%
# Current time can be initialized by leaving out any arguments
print(UTCDateTime())
# Out:
# 2026-02-12T16:27:16.349245Z

# %% [markdown]
# #### Attribute Access

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time.year)
print(time.julday)
print(time.timestamp)
print(time.weekday)
# try time.<Tab>
print(time.isoformat)
# Out:
# 2011
# 70
# 1299822383.2
# 4
# <bound method UTCDateTime.isoformat of UTCDateTime(2011, 3, 11, 5, 46, 23, 200000)>

# %% [markdown]
# #### Handling time differences
#
# * "**`+`**/**`-`**" defined to add seconds to an **`UTCDateTime`** object
# * "**`-`**" defined to get time difference of two **`UTCDateTime`** objects

# %%
time = UTCDateTime("2011-03-11T05:46:23.200000Z")
print(time)
# Out:
# 2011-03-11T05:46:23.200000Z

# %%
# one hour later
print(time + 3600)
# Out:
# 2011-03-11T06:46:23.200000Z

# %%
time2 = UTCDateTime(2012, 1, 1)
print((time2 - time)/(24*3600))
secondsPerDay = 60 * 60 * 24
print((time2 - time)/secondsPerDay)
# Out:
# 295.7594537037037
# 295.7594537037037

# %% [markdown]
# ### Exercises
#
# Calculate the number of days passed since the Tohoku main shock (the timestamp used above).

# %%
time3 = UTCDateTime()
print(UTCDateTime.now())
print(time3)
print(time)
print((time3 - time) / secondsPerDay)
# Out:
# 2026-02-12T16:38:12.850084Z
# 2026-02-12T16:38:12.850035Z
# 2011-03-11T05:46:23.200000Z
# 5452.452657986517

# %% [markdown]
# Make a list of 10 UTCDateTime objects, starting today at 10:00 with a spacing of 90 minutes.

# %%
time4 = UTCDateTime("2026-02-12T10:00:00.0")
nintyMin = 90 * 60
i = 1
# also works:
#for i in range(1, 10):
    # print(time4 + i * nintyMin)
# empty list
# my_list = list()
my_list1 = []
# for i in range(10): is same going from 0 to 9
for i in range(0, 9):
    # my_list.append(time4 + i * nintyMin)
    # print(my_list[-1])
    t8 = time4 + i * nintyMin
    my_list1.append(t8)
# print(my_list)
print(my_list1)
# Out:
# [UTCDateTime(2026, 2, 12, 10, 0), UTCDateTime(2026, 2, 12, 11, 30), UTCDateTime(2026, 2, 12, 13, 0), UTCDateTime(2026, 2, 12, 14, 30), UTCDateTime(2026, 2, 12, 16, 0), UTCDateTime(2026, 2, 12, 17, 30), UTCDateTime(2026, 2, 12, 19, 0), UTCDateTime(2026, 2, 12, 20, 30), UTCDateTime(2026, 2, 12, 22, 0)]

# %% [markdown]
# Below is a list of strings with origin times of magnitude 8+ earthquakes since 2000 (fetched from IRIS). Assemble a list of interevent times in days. Use matplotlib to display a histogram.

# %%
times = ["2001-06-23T20:33:09",
         "2003-09-25T19:50:07",
         "2004-12-23T14:59:00",
         "2004-12-26T00:58:52",
         "2005-03-28T16:09:35",
         "2006-06-01T18:57:02",
         "2006-06-05T00:50:31",
         "2006-11-15T11:14:14",
         "2007-01-13T04:23:23",
         "2007-04-01T20:39:56",
         "2007-08-15T23:40:58",
         "2007-09-12T11:10:26",
         "2009-09-29T17:48:11",
         "2010-02-27T06:34:13",
         "2011-03-11T05:46:23",
         "2012-04-11T08:38:36",
         "2012-04-11T10:43:10",
         "2013-05-24T05:44:48"]
# print(times)
utcdt = [UTCDateTime(t) for t in times]
print(utcdt)
# Out:
# [UTCDateTime(2001, 6, 23, 20, 33, 9), UTCDateTime(2003, 9, 25, 19, 50, 7), UTCDateTime(2004, 12, 23, 14, 59), UTCDateTime(2004, 12, 26, 0, 58, 52), UTCDateTime(2005, 3, 28, 16, 9, 35), UTCDateTime(2006, 6, 1, 18, 57, 2), UTCDateTime(2006, 6, 5, 0, 50, 31), UTCDateTime(2006, 11, 15, 11, 14, 14), UTCDateTime(2007, 1, 13, 4, 23, 23), UTCDateTime(2007, 4, 1, 20, 39, 56), UTCDateTime(2007, 8, 15, 23, 40, 58), UTCDateTime(2007, 9, 12, 11, 10, 26), UTCDateTime(2009, 9, 29, 17, 48, 11), UTCDateTime(2010, 2, 27, 6, 34, 13), UTCDateTime(2011, 3, 11, 5, 46, 23), UTCDateTime(2012, 4, 11, 8, 38, 36), UTCDateTime(2012, 4, 11, 10, 43, 10), UTCDateTime(2013, 5, 24, 5, 44, 48)]
